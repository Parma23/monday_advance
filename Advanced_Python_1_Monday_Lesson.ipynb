# %% [markdown]
# # Coding Temple's Data Analytics Course
# ---
# ## Advanced Python Day 1: Regular Expressions

# %% [markdown]
# ## Tasks today:
# 1) <b>Importing</b> <br>
# 2) <b>Using Regular Expressions</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) re.compile() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) re.match() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) re.findall() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) re.search() <br>
# 3) <b>Sets</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Integer Ranges <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Character Ranges <br>
# 4) <b>Counting Occurences</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) {x} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) {, x} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) {?} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) {*} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) {+} <br>
# 5) <b>In-Class Exercise #1</b> <br>
# 6) <b>Escaping Characters</b> <br>
# 7) <b>Grouping</b> <br>
# 8) <b>In-Class Exercise #2</b> <br>
# 9) <b>Opening a File</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) open() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) with open() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) re.match() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) re.search() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Store the String in a Variable <br>
# 10) <b>Regex Project</b> <br>

# %% [markdown]
# ### Importing <br>
# <p>Regular Expressions are universal throughout most programming languages... They are generally imported through the module 're'.</p>

# %% [markdown]
# ### Using Regular Expressions <br>
# <p>Regular expressions give us the ability to search for patterns within text, strings, files, etc. They serve several uses, such as; security measures, searching, filtering, pattern recognition, and more...</p>

# %% [markdown]
# ##### re.compile()

# %% [markdown]
# ##### re.match()

# %% [markdown]
# ##### re.findall()

# %% [markdown]
# ##### re.search()

# %% [markdown]
# ### Sets <br>
# <p>The following cells will allow you to use regular expressions to search for certain values within a range such as numbers 1 through 4.</p>

# %% [markdown]
# ##### [a-z] or [A-Z] - any lowercase/uppercase letters from a to z<br/>[^2] - anything that's not 2

# %% [markdown]
# ##### Integer Ranges

# %% [markdown]
# ##### Character Ranges

# %% [markdown]
# ### Counting Occurences

# %% [markdown]
# ##### {x} - something that occurs {num_of_times}

# %% [markdown]
# ##### {x, x} - something that occurs between x and x times

# %% [markdown]
# ##### ? - something that occurs 0 or 1 time

# %% [markdown]
# ##### * - something that occurs at least 0 times

# %% [markdown]
# ##### + - something that occurs at least once

# %% [markdown]
# ##### In-class exercise 1:
#
# Use a regular expression to find every number in the given string

# %%
my_string = 'This string has 10909090 numbers, but it is only 1 string. I hope you solve this 2day'
# Output: ['10909090', '1', '2']
st1 = re.compile('[0-9]{1,8}')
was1 = st1.findall(my_string)
print(was1)

diffrent way 

re.findall('[*0-9]+')

found = pattern.findall(my_string)
print (found)

# %% [markdown]
# ### Escaping Characters

# %% [markdown]
# ##### \w - look for any Unicode character<br/>\W - look for anything that isnt a Unicode character
#
# [History on Unicode](http://unicode.org/standard/WhatIsUnicode.html)
#
# [More on Unicode Characters](https://en.wikipedia.org/wiki/List_of_Unicode_characters)

# %% [markdown]
# ##### \d - look for any digit 0-9<br/>\D - look for anything that isnt a digit

# %%
date = 'today is the 15th. in 16 days it will be the list.'
"""
what does this compile statement do ? it search for any occurance of 1-2 digits, follows by anything 
that isn't a number and occurs twoice.
"""
pattern_num - re.compile('/d{1,2}[/D]{2}')

# %% [markdown]
# ##### \s - look for any white space<br/>\S - look for anything that isnt whitespace

# %%
string = ' are you   afraid of the drak?'


pattern_no_space = re.compile('\S[a-z]+')
found_dark = pattern_no_space.findall(string)
print(found_dark)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 string = ' are you   afraid of the drak?'
# ----> 4 pattern_no_space = re.compile('\S[a-z]+')
#       5 found_dark = pattern_no_space.findall(string)
#       6 print(found_dark)
#
# NameError: name 're' is not defined

# %% [markdown]
# ##### \b - look for boundaries or edges of a word<br/>\B - look for anything that isnt a boundary

# %%
# complile that uses a string objeck and  a/b
pattern_bound = re.compile(r'\bThecodingtample\')

# %% [markdown]
# ### Grouping

# %%
my_string_again = "max smith, arron rodgers, sam Darnold, labron James, "
pattern_name = re.compile('[A-Z')

# %% [markdown]
# ##### In-class Exercise 2:
#
# Write a function using regular expressions to find the domain name in the given email addresses (and return None for the invalid email addresses)<br><b>HINT: Use '|' for either or</b>

# %%
my_emails = ["jordanw@codingtemple.orgcom", "pocohontas1776@gmail.com", "helloworld@aol..com",
             "yourfavoriteband@g6.org", "@codingtemple.com"]

# You can also use the $ at the end of your compile expression -- this stops the search

#.com OR .org => com|org
def validate_email(my_emais):
   pattern = re.compile("([A-Za-z0-9]+)@([A-Za-z0-9]+).(org$| com)")
   if pattern.match(email)
        return my_email
   else
       return None
   for email in my_emails:
       print validate.email

d= pattern.findall(string)
print(found)
    
#Expected output:
#None
#pocohontas1776@gmail.com
#None
#yourfavoriteband@g6.org
#None
# Out:
#   Cell In[5], line 8
#     pattern = re.compile('\u[a-z]+')
#                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \uXXXX escape

# %% [markdown]
# ### Opening a File <br>
# <p>Python gives us a couple ways to import files, below are the two used most often.</p>

# %% [markdown]
# ##### open()

# %% [markdown]
# ##### with open()

# %% [markdown]
# ##### re.search()

# %% [markdown]
# ##### Store the String to a Variable

# %% [markdown]
# ### In-Class Exercise #3 <br>
# <p>Print each persons name and twitter handle, using groups, should look like:</p>
# <p>==============<br>
#    Full Name / Twitter<br>
#    ==============</p>
# Derek Hawkins / @derekhawkins
#
#  Erik Sven-Osterberg / @sverik
#
#  Ryan Butz / @ryanbutz
#
#  Example Exampleson / @example
#
#  Ripal Pael / @ripalp
#
#  Darth Vader / @darthvader

# %%
import re

def print_name_and_twitter(data):
    f = 
    pattern = 
        # Comment: 
        print(f.read())
    # end open file
    
    print("")
    print("Full Name / Twitter")
    print("")
    
    matches = re.findall(pattern, data)
    
    for match in matches:
        full_name, twitter_handle = match
        print(f"{full_name} / {twitter_handle}")

# Example usage:
data = """
Derek Hawkins / @derekhawkins
Erik Sven-Osterberg / @sverik
Ryan Butz / @ryanbutz
Example Exampleson / @example
Ripal Pael / @ripalp
Darth Vader / @darthvader
"""

print_name_and_twitter(data)

# %% [markdown]
# ### Regex project
#
# Use python to read the file regex_test.txt and print the last name on each line using regular expressions and groups (return None for names with no first and last name, or names that aren't properly capitalized)
# ##### Hint: use with open() and readlines()

# %% [markdown]
# import.re
# open(r'/Users/paaracharya/Downloads/names.txt)
# pattern.read()

# %%
"""
Expected Output
Abraham Lincoln
Andrew P Garfield
Connor Milliken
Jordan Alexander Williams
None
None
"""

import re

def last_name1(line):
    pattern = r'^[A-Z][a-zA-Z]*\s([A-Z][a-z][A-Z]*)$'
    match = re.match(pattern, line)

    if match:
        return match.group(1)
    else:
        return None

with open((r'/Users/paaracharya/Downloads/names.txt)) as file:
    lines = file.readlines()

for line in lines:
    last_name = last_name1(line.strip())
    print(last_name)
# Out:
#   Cell In[8], line 22
#     with open((r'/Users/paaracharya/Downloads/names.txt)) as file:
#                ^
# SyntaxError: unterminated string literal (detected at line 22)
